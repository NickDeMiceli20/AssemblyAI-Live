# %% [markdown]
# <a href="https://colab.research.google.com/github/NickDeMiceli20/AssemblyAI-Live/blob/main/EarningsEdgeSentimentClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# !pip install openai
import openai
openai.api_key = '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'
from langchain import PromptTemplate
from langchain import OpenAI
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting langchain
#   Downloading langchain-0.0.163-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.0/782.0 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.10)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 10.6 MB/s eta 0:00:00
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.22.4)
# Collecting openapi-schema-pydantic<2.0,>=1.2 (from langchain)
#   Downloading openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.10.7)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.27.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.2)
# Requirement already satisfied: tqdm>=4.48.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.65.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 4.8 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 7.5 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 7.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting marshmallow<4.0.0,>=3.3.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain)
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 2.2 MB/s eta 0:00:00
# Collecting marshmallow-enum<2.0.0,>=1.5.1 (from dataclasses-json<0.6.0,>=0.5.7->langchain)
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting typing-inspect>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain)
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2,>=1->langchain) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (23.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, multidict, marshmallow, frozenlist, async-timeout, yarl, typing-inspect, openapi-schema-pydantic, marshmallow-enum, aiosignal, dataclasses-json, aiohttp, langchain
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 dataclasses-json-0.5.7 frozenlist-1.3.3 langchain-0.0.163 marshmallow-3.19.0 marshmallow-enum-1.5.1 multidict-6.0.4 mypy-extensions-1.0.0 openapi-schema-pydantic-1.2.4 typing-inspect-0.8.0 yarl-1.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.6-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# Successfully installed openai-0.27.6

# %%
import os

# Specify the directory containing the text files
dir_path = "./"

# Create an empty dictionary to store the file contents
file_contents = {}

# Loop through all the text files in the directory
for file_name in os.listdir(dir_path):
    if file_name.endswith(".txt"):
        # Read the contents of the file
        with open(os.path.join(dir_path, file_name), "r") as f:
            content = f.read()
        # Save the file contents as a variable with the file name as the variable name
        var_name = file_name[:-4]  # remove the .txt extension from the file name
        globals()[var_name] = content  # create a new variable with the file name as the variable name
        file_contents[var_name] = content  # store the file contents in the dictionary

# Print the names of all the variables that were created
print(file_contents['Q1_4_19_2023'])
for var_name in file_contents.keys():
    print(var_name)

# %%
import openai
import os

openai.api_key = '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'

# Define a function to analyze sentiment
def analyze_sentiment(sentence):
    prompt = f"""
    You are a successful finance analyst. You understand the numbers and meaning in a sentence and are able to accurately depict the sentiment of
    sentences. You understand words can be misinterepreted in finance and do not allow yourself to be fooled. You will return
    1.0 for positive statements, 2.0 for positive statements that are extremely important to the company and can help swing their future, -1.0 for Negative
    statements, -2.0 for negative statements that are extremely important to the company and could diminish their future, and lastly 0 for neutral. 
    Any statements that have no relevance to finance or the company and are opening remarks, such as hello or goodmorning, return as neutral.
    You will always just print the integer you feel the sentiment is, nothing else. 
    Sentence: Cost of goods sold increased over 30%
  -2

  Sentence: Revenue decreased over 30%
  -2

  Sentence: ARR increased over 50% 
  2

  Sentence: Average churn rate increased over 10%
  -2

  Sentence: We believe we will decrease our expenses throughout the rest of this fiscal year
  1

  Sentence: Operating expenses exceeded our expectations
  -1

  Sentence: Good Morning
  0

  Sentence: These are forward looking statements for the future
  0

  Sentence: Actual events or results could differ materially due to a number of risks and uncertainties, including those mentioned in our most recent filings with the SEC
  0


  Sentence: {sentence}

    """
    response = openai.Completion.create(
    engine="text-davinci-003", 
    prompt=prompt,
    temperature=0.1,
    max_tokens=60)
    
    # Extract the sentiment score from the model's output
    sentiment_text = response.choices[0].text.strip()
    sentiment_score = None
    
    try:
        sentiment_score = float(sentiment_text.split('\n')[-1])
    except ValueError:
        print(f"Unexpected response from model: {sentiment_text}")
    
    return sentiment_score

# Analyze sentiment for each earnings call
content = file_contents['Q1_4_29_2020']
sentences = content.split('.')
total_sentiment = 0
for sentence in sentences:
  sentiment = analyze_sentiment(sentence)
  total_sentiment += sentiment
  print(f"Sentence {sentence}, Sentiment Score: {sentiment}")
print(total_sentiment)
# Out:
# Sentence Tesla, Inc, Sentiment Score: 0.0
# Sentence  (NASDAQ:TSLA) Q1 2020 Earnings Conference Call April 29, 2020 6:30 PM ET Company Participants Martin Viecha - Senior Director for Investor Relations Elon Musk - Co-Founder & Chief Executive Officer Zachary Kirkhorn - Chief Financial Officer Conference Call Participants Adam Jonas - Morgan Stanley Emmanuel Rosner - Deutsche Bank Ben Kallo - Baird Gene Munster - Loup Ventures Pierre Ferragu - New Street Operator Ladies and gentlemen, thank you for standing by, and welcome to Tesla's Q1 2020 Financial Results and Q&A Webcast, Sentiment Score: 0.0
# Sentence  At this time, all participants are in a listen-only mode, Sentiment Score: 0.0
# Sentence  After the speaker presentation, there will be a question-and-answer session, Sentiment Score: 0.0
# Sentence  [Operator Instructions] Please be advised that today's conference is being recorded, Sentiment Score: 0.0
# Sentence  [Operator Instructions] I would now like to hand the conference over to your speaker, Mr, Sentiment Score: 0.0
# Sentence  Martin Viecha, Senior Director for Investor Relations, Sentiment Score: 0.0
# Sentence  Please go ahead, sir, Sentiment Score: 0.0
# Sentence  Martin Viecha Thank you, Sherry, and good afternoon, everyone, Sentiment Score: 0.0
# Sentence  Welcome to Tesla's First Quarter 2020 Q&A Webcast, Sentiment Score: 0.0
# Sentence  I'm joined today by Elon Musk, Zachary Kirkhorn and a number of other executives, Sentiment Score: 0.0
# Sentence  Our Q1 results were announced at about 1:00 p, Sentiment Score: 0.0
# Sentence m, Sentiment Score: 0.0
# Sentence  Pacific Time in the update deck we published at the same link as this webcast, Sentiment Score: 0.0
# Sentence  During this call, we will discuss our business outlook and make forward-looking statements, Sentiment Score: 0.0
# Sentence  These comments are based on our predictions and expectations as of today, Sentiment Score: 1.0
# Sentence  Actual events or results could differ materially due to a number of risks and uncertainties, including those mentioned in our most recent filings with the SEC, Sentiment Score: -2.0
# Sentence  During the question-and-answer portion of today's call, please limit yourself to one question and one follow-up, Sentiment Score: 0.0
# Sentence  [Operator Instructions] Before we jump into Q&A, Elon has some opening remarks, Sentiment Score: 0.0
# Sentence  Elon? Elon Musk Thank you, Sentiment Score: 0.0
# Sentence  So, Q1 ended up being a strong quarter despite many challenges in the final few weeks, Sentiment Score: 1.0
# Sentence  This is the first time we have achieved positive GAAP net income in a seasonally weak first quarter, Sentiment Score: 2.0
# Sentence  Even with all the challenges, we achieved a 20% automotive gross margin, excluding regulatory credits while ramping two major products, Sentiment Score: 2.0
# Sentence  What we've learned from this is that -- we've obviously learned a lot here, Sentiment Score: 0.0
# Sentence  After the Model 3 ramp from three years ago, our new products get run faster and become profitable sooner, Sentiment Score: 2.0
# Sentence  In Q1, we produced more Model Ys in the first quarter than Model 3s in Fremont in the first two quarters, Sentiment Score: 0.0
# Sentence  Thus far, the Model Y ramp has been even faster than the Giga Shanghai ramp in Q1, Sentiment Score: 2.0
# Sentence  Most surprisingly, as otherwise, we are ahead of the schedule that we were ahead of already, Sentiment Score: 0.0
# Sentence  Most surprisingly, Model Y was profitable already in its first quarter of production, something we haven't achieved with any product in the past, Sentiment Score: 2.0
# Sentence  Regarding Autopilot, we released a new software update for traffic lights and stop signs to Early Access Users in March and to all U, Sentiment Score: 1.0
# Sentence S, Sentiment Score: 0.0
# Sentence  customers with Full Self-Driving package just last week, Sentiment Score: 0.0
# Sentence  Our cars will not automatically stop at each stop sign or traffic light until the driver gets a confirmation to proceed, Sentiment Score: 0.0
# Sentence  I should say that the car is actually capable of much more than this, but we are only exposing functionality that we feel quite good about and where we feel it is probably a safety improvement, Sentiment Score: 0.0
# Sentence  We are collecting data from over 1 million intersections every month at this point, Sentiment Score: 0.0
# Sentence  This number will grow exponentially as more people get the update and as more people start driving again, Sentiment Score: 0.0
# Sentence  Soon, we will be collecting data from over 1 billion intersections per month, Sentiment Score: 1.0
# Sentence  All of those confirmations are training under old methods, Sentiment Score: 0.0
# Sentence  Essentially, the driver went driving and taking action is effectively labeling -- the labeling reality as they drive and making them better and better, Sentiment Score: 0.0
# Sentence  I think this is an advantage that no one else has, and we're quite literally orders of magnitude more than everyone else combined, Sentiment Score: 0.0
# Sentence  I think, this is difficult to fully appreciate, Sentiment Score: 0.0
# Sentence  It’s the reason I say it's very difficult to have a search engine that competes with Google because everyone is training Google all the time with their searches, Sentiment Score: 0.0
# Sentence  So, when you're searching something and you click on a link, you're training Google every time you do that, Sentiment Score: 0.0
# Sentence  It's very difficult for any new search engine to compete on that basis, Sentiment Score: 0.0
# Sentence  So, all those confirmations of training and all that, and certain cars will be able to drive through an intersection without a confirmation as well as to make turns, Sentiment Score: 0.0
# Sentence  And we really feel we're -- I feel extremely confident that it would be possible to do a drive from your home to your office most of the time with no interventions by the end of the year, Sentiment Score: 0.0
# Sentence  So, this is -- we can almost do this already with the leading-edge Alpha [indiscernible] driving the car, Sentiment Score: 0.0
# Sentence  So let's see, Sentiment Score: 0.0
# Sentence  On other technology fronts, we increased the range of model S and X yet again, this time to 391 miles for Model S and 351 miles for Model X, Sentiment Score: 1.0
# Sentence  Actually, we said that, actually, the model -- the real Model S range is 400 miles, but when we did the last EPA test, unfortunately, ATA left the car door open and the keys in the car, so the car - and it did this overnight, Sentiment Score: 0.0
# Sentence  And so the car actually went into waiting for driver mode and lost 2% of its range, Sentiment Score: 0.0
# Sentence  And as a result, it had a 391 test, Sentiment Score: 0.0
# Sentence  As soon as the EPA reopens for testing, we will redo the test, and we're actually confident that we will achieve a 400-mile-or-greater range with the Model S, Sentiment Score: 1.0
# Sentence  But to be clear, the Model S, for the past two months -- the true range of the Model S for the past two months has been 400 miles, Sentiment Score: 0.0
# Sentence  And of course, we're not stopping there, Sentiment Score: 1.0
# Sentence  We're looking forward to continuing pushing for improved range over time and improving handling, acceleration and all those details that make Tesla special, Sentiment Score: 0.0
# Sentence  For Model Y, we introduced a revolutionary two-piece -- we're underway casting that we are going to be making a single-piece casting later this year, meaning like essentially the rear third of the body is cast as a single piece, which is no casting of the size or complexity has never been done before, Sentiment Score: 0.0
# Sentence  In fact, there isn't even anything that is on par with the two-piece casting for the Model Y, Sentiment Score: 0.0
# Sentence  So, we're really pushing the envelope on vehicle structural engineering and manufacturing, Sentiment Score: 0.0
# Sentence  I'm very excited about this approach as it allows us to reduce the weight of the cast and improve NVH, Sentiment Score: 0.0
# Sentence  It's better in every way essentially, Sentiment Score: 0.0
# Sentence  For Model Y, we also introduced a revolutionary new heat pump, which allows the car to have a higher range, Sentiment Score: 0.0
# Sentence  So Model Y has remarkable range on par with -- in fact slightly better than, I guess, the Model 3 and just despite being a bigger car that weighs more, Sentiment Score: 0.0
# Sentence  And the heat pump is a key contributor to that, Sentiment Score: 0.0
# Sentence  It is especially excellent at low-temperature driving, Sentiment Score: 0.0
# Sentence  So -- and the feedback we're getting from customers who have received the Model Y thus far has been universally positive, Sentiment Score: 1.0
# Sentence  We're confident this product will be our best-selling product ever, Sentiment Score: 2.0
# Sentence  So in conclusion, and just to -- looking forward, I guess this is a forward-looking statement we are absolutely continuing our Model Y capacity expansion at full speed at both Giga Berlin and Giga Shanghai and here in Fremont when they will let us continue, Sentiment Score: 0.0
# Sentence  Localized production in China and in Europe will bring the cost down, making our products even more competitive over time, Sentiment Score: 1.0
# Sentence  While many other companies are cutting back on investment, we are doing the opposite, Sentiment Score: 2.0
# Sentence  We're absolutely pedal to the metal on new products and expanding the company, Sentiment Score: 1.0
# Sentence  And we're really looking forward to being in sometime next year, a truly global manufacturer with major factories in North America, China and Europe and a capacity of well over 1 million units a year, Sentiment Score: 0.0
# Sentence  So there's a tremendous amount to look forward to and we can't wait to tell you what's going to happen, Sentiment Score: 1.0
# Sentence  Thank you, Sentiment Score: 0.0
# Sentence  Martin Viecha Thank you, Sentiment Score: 0.0
# Sentence  And now to Zach's opening remarks, Sentiment Score: 0.0
# Sentence  Zachary Kirkhorn Yes, Sentiment Score: 0.0
# Sentence  Thanks, Martin and thanks, Elon, Sentiment Score: 0.0
# Sentence  I'm very proud of the accomplishments of the Tesla team this past quarter, Sentiment Score: 0.0
# Sentence  A few things to highlight and add to what Elon just mentioned, Sentiment Score: 0.0
# Sentence  We successfully launched, ramped and demonstrated profitability of the Model Y, as Elon mentioned, significantly ahead of schedule, Sentiment Score: 2.0
# Sentence  This is our second large-scale product launch since Model 3 in 2017 and it's evidence to the progress we've made on cost control and ramp efficiency, Sentiment Score: 1.0
# Sentence  It's hard to understate the significance of demonstrating profitability of this program in its first quarter of production, Sentiment Score: 2.0
# Sentence  Our Shanghai Model 3 margins improved dramatically since Q4 of last year, nearing equivalents of Model 3s built in Fremont, Sentiment Score: 2.0
# Sentence  This is despite not yet running at full capacity, while also managing through the production shutdown in early February, Sentiment Score: 1.0
# Sentence  We also announced a long-range and performance variant of Model 3 for our road map, which will positively impact ASPs in China, Sentiment Score: 2.0
# Sentence  On order rates, we did not experience much of an impact related to the expiration of government incentives at the end of Q4, Sentiment Score: 0.0
# Sentence  In fact, we exited the quarter with our highest-ever backlog yet again, Sentiment Score: 2.0
# Sentence  Aided by these accomplishments, we are able to achieve our first-ever Q1 profit, Sentiment Score: 2.0
# Sentence  Automotive gross margin, excluding the impact of regulatory credits, remained strong for all products, despite charges taken in Q1 associated with production downtime, Sentiment Score: 1.0
# Sentence  We continue to make progress on OpEx efficiency, as well as our service and other margins, Sentiment Score: 1.0
# Sentence  Our energy business was impacted as well by shutdown activities in Q1 limiting deployments, Sentiment Score: -1.0
# Sentence  We also experienced expected launch efficiencies associated with our third version of the Solar Roof, which impacted overall profitability, Sentiment Score: -1.0
# Sentence  As I've noted before, we expect regulatory credit sales, which our credits we sell to other carmakers to generally increase with time, Sentiment Score: 1.0
# Sentence  This can be seen by the increase from Q1 relative to Q4, Sentiment Score: 0.0
# Sentence  And note that most of the credit revenue did not contribute to cash in Q1, and it's reflected in the accounts receivable on the balance sheet, Sentiment Score: 0.0
# Sentence  Our free cash flows were impacted by the temporary – by the temporary increase in end of quarter inventory for all our products resulting from the abrupt suspension of production and delivery operations, Sentiment Score: -2.0
# Sentence  Had these interruptions not occurred, we were pacing towards a record quarter of deliveries and strong free cash flows, Sentiment Score: 2.0
# Sentence  As Elon mentioned, it is extremely important that we remain on track to achieve our long-term plans and technology road map, Sentiment Score: 2.0
# Sentence  We are taking the near-term actions required to continue those investments, Sentiment Score: 1.0
# Sentence  Model Y in Shanghai and Berlin are proceeding as planned and we're making progress on improving capacity for Model Y in Fremont and Model 3 in Shanghai, Sentiment Score: 1.0
# Sentence  In the near term, our Shanghai factory remains operational, contributing an increasing level of cash flows and profitability to the company, Sentiment Score: 1.0
# Sentence  In Fremont, we're working towards restarting production as soon as that's possible, Sentiment Score: 0.0
# Sentence  We are also continuing to deliver cars that we were unable to deliver at the end of the first quarter, Sentiment Score: 1.0
# Sentence  Our vehicle inventory balance increased by 14,000 units at the end of Q1, which was a headwind to free cash flows in Q1, but it's helpful in Q2, Sentiment Score: 1.0
# Sentence  Note that one of the most important aspects of Model Y in Fremont and Model 3 in Shanghai is the dramatically improved cash conversion cycle by locally producing and delivering vehicles, Sentiment Score: 2.0
# Sentence  While sales and delivery operations have paused in many areas of the world, we are still receiving many online orders, despite inability for our customers to experience the product prior to ordering, Sentiment Score: 1.0
# Sentence  However, unavoidably, the extended shutdown in Fremont will have an impact on our near-term financial performance and we will need to work through how quickly we'll be able to ramp production to prior levels, Sentiment Score: -1.0
# Sentence  More broadly, we remain focused on ensuring our cash flows are managed appropriately, Sentiment Score: 1.0
# Sentence  Working capital management, in particular, raw material inventory is the single most important lever in managing our cash flows during this time, Sentiment Score: 1.0
# Sentence  The Tesla team has done a great job here, Sentiment Score: 0.0
# Sentence  We've also taken actions to eliminate or reduce non-critical expenses and optional investments while continuing to drive efficiencies throughout the business, Sentiment Score: 1.0
# Sentence  Overall, we've modeled many scenarios into 2021 and remain comfortable that we have sufficient liquidity to proceed fully with our most important, long-term investments, Sentiment Score: 1.0
# Sentence  It is important to note that Tesla remains an extremely agile and dynamic company, and this is aided by the substantial work we've done over the last year to improve our cost efficiency and productivity, Sentiment Score: 1.0
# Sentence  And we have the ability to quickly adjust our spending and planning as required, Sentiment Score: 1.0
# Sentence  So thank you again to the Tesla team for success in Q1, and we will turn to questions, Sentiment Score: 0.0
# Sentence  Martin Viecha Thank you very much, Sentiment Score: 0.0
# Sentence  So we'll take the first questions from institutional investors compiled by Safe Technologies, Sentiment Score: 0.0
# Sentence  Question-and-Answer Session A - Martin Viecha The first question from institutional investor is, most Tesla owners have yet to purchase or experience FSD, despite most vehicles having all the necessary hardware, Sentiment Score: 0.0
# Sentence  What levers could you pull to accelerate adoption and deepen your data advantage? For example, could you consider offering FSD as a premium subscription? Elon Musk I think we will offer Full Self-Driving as a subscription service, but it will be probably towards the end of this year, Sentiment Score: 0.0
# Sentence  I should say, it will still make sense to buy FSD as an option as in our view, buying FSD is an investment in the future, Sentiment Score: 2.0
# Sentence  And we are confident that it is investment that will pay off to the consumer -- to the benefit of the consumer, Sentiment Score: 1.0
# Sentence  In my opinion, buying FSD option is something people will not regret doing, Sentiment Score: 0.0
# Sentence  Zachary Kirkhorn Agree, Sentiment Score: 0.0
# Sentence  And financially, rolling the upfront purchase of your -- of the FSD option into a loan in the vehicle or a lease is – will be the least expensive plan on a monthly basis to own, plus you preserve the option value of increased value of time, Sentiment Score: 0.0
# Sentence  So we do understand that some customers who have ownership or have leased their vehicles did not purchase that option upfront, Sentiment Score: 0.0
# Sentence  And so this will enable those customers to spread out the cost of ownership of FSD or subscription over time, Sentiment Score: 0.0
# Sentence  Elon Musk Yes, absolutely, Sentiment Score: 0.0
# Sentence  At a high level, our overall goal is to maximize the area under the curve of customer happiness, Sentiment Score: 0.0
# Sentence  That is our goal, Sentiment Score: 0.0
# Sentence  And we think that, that's the kind of thing that all companies should try to do, Sentiment Score: 0.0
# Sentence  And it's what results in long-term value creation and loyalty – the guest loyalty, Sentiment Score: 0.0
# Sentence  So our goal is always really to do the best thing for the customers, and we're confident that if we behave like that, the customers in turn will behave the same way to us, Sentiment Score: 0.0
# Sentence  Martin Viecha Thank you, Sentiment Score: 0.0
# Sentence  The second question from investors is, China recently announced changes to its NEV subsidy program that disqualifies Tesla vehicles from benefiting from the subsidies, Sentiment Score: 0.0
# Sentence  To what extent is there room for Tesla to lower manufacturing costs in China and pass those savings to buyer, so they can qualify for the subsidy? Elon Musk Yes, Sentiment Score: 0.0
# Sentence  So we are making rapid progress on lowering the production costs in China, Sentiment Score: 1.0
# Sentence  And we're actually excited to announce on this call that we will be reducing the price of the standard range Model 3 basically tomorrow, China time, Sentiment Score: 1.0
# Sentence  So the day after tomorrow, California time, but tomorrow, China time, Sentiment Score: 0.0
# Sentence  And there will be a price below the subsidy limit, Sentiment Score: 0.0
# Sentence  And we feel confident that that's will still be a vehicle that delivers a good gross margin, Sentiment Score: 1.0
# Sentence  Zachary Kirkhorn Yes, Sentiment Score: 0.0
# Sentence  And on the manufacturing cost portion of the question, the cost of vehicles produced in Shanghai in Q1 is already lower than the cost to produce the Model 3 in Fremont, and there's still significant opportunity left to take costs out, Sentiment Score: 1.0
# Sentence  So fixed cost absorption from higher production volumes, which are occurring in Q2 and will occur through the rest of the year were not fully localized on the supply chain yet, Sentiment Score: 0.0
# Sentence  And so while a lot of the supply chain is localized, it's not complete, and there's additional opportunities there, Sentiment Score: 0.0
# Sentence  And so we'll continue to bring the price down and expand margin -- costs down and expand margin even with this reduction in price that Elon mentioned on the standard range version of the vehicle, Sentiment Score: 0.0
# Sentence  Martin Viecha Thank you, Sentiment Score: 0.0
# Sentence  The next question is, Andy Grove once said that great companies are improved by crisis, Sentiment Score: 0.0
# Sentence  In which way has Tesla improved towards -- or is expected to improve coming out of COVID-19? Elon Musk Well, it has caused us to look closely at our cost structure and to be more efficient as a company, Sentiment Score: 0.0
# Sentence  That's one always has to do that in a crisis, and just thinking about our core beliefs and what do we want to do, Sentiment Score: 0.0
# Sentence  And we came to a conclusion that at the right move was actually to continue to expand rapidly, continue to invest in the future and in new technologies, even though it is risky, Sentiment Score: 1.0
# Sentence  And we've talked to some of our key investors, and they support that approach as well, Sentiment Score: 1.0
# Sentence  So I think that there's clearly an uncertain future ahead, Sentiment Score: 0.0
# Sentence  It's a bit of a bumpy road, Sentiment Score: 0.0
# Sentence  But I think the long-term prospects are extremely good, Sentiment Score: 2.0
# Sentence  Anything you guys want to add? Zachary Kirkhorn Yeah, I agree with Elon, Sentiment Score: 0.0
# Sentence  The prioritization on the key projects will enable us to execute more efficiently and faster on them, which I think is great, Sentiment Score: 1.0
# Sentence  The other one that I would add is, it's always been our vision at Tesla to improve the customer experience and make that as digital as possible, Sentiment Score: 0.0
# Sentence  Elon Musk Yes, Sentiment Score: 0.0
# Sentence  Touchless delivery, Sentiment Score: 0.0
# Sentence  Zachary Kirkhorn Yeah, So touchless delivery, Sentiment Score: 0.0
# Sentence  Mobile service touchless sales has been something that we've been very focused on and made a lot of progress on, Sentiment Score: 1.0
# Sentence  Elon Musk Yes, Sentiment Score: 0.0
# Sentence  The Tesla is the only car that you can literally order in less than five minutes on your phone, you can order a car and have it delivered to your doorstep with all the paper and everything done, Sentiment Score: 0.0
# Sentence  That's it, Sentiment Score: 0.0
# Sentence  Effortless, Sentiment Score: 0.0
# Sentence  Zachary Kirkhorn And many customers do that, Sentiment Score: 0.0
# Sentence  Elon Musk And they're doing it, yes, Sentiment Score: 0.0
# Sentence  In fact, a big part of it is just trying to communicate to people that this is something you can do, because normally, buying a car is quite a pain -- for most people, they would rather go to the dentist than buy a new car, Sentiment Score: 0.0
# Sentence  Actually, my dentist is very -- but it's really like quite an arduous thing, Sentiment Score: 0.0
# Sentence  When the typical retail experience for buying a new car is more painful to people than having a root canal done, then you have to say, well -- and for Tesla, it is completely as easy as ordering something from the Apple App Store or something on Amazon and -- except it's a car, Sentiment Score: 0.0
# Sentence  Yes, Sentiment Score: 0.0
# Sentence  All right, Sentiment Score: 0.0
# Sentence  And then five minutes is a, if you really went fast, I think you could order a car probably in 90 seconds, so, Sentiment Score: 0.0
# Sentence  Martin Viecha The next question is from institutional investor is, can you give us a brief preview of the Battery Day by generally highlighting steps Tesla is taking to improve cell energy density and time line for introduction? Elon Musk Yes, Sentiment Score: 0.0
# Sentence  Actually, we were just -- we don't want to preempt Battery Day, Sentiment Score: 0.0
# Sentence  We want to leave the exciting news for that day, but there will be a lot of exciting news to tell, Sentiment Score: 0.0
# Sentence  And I think it would be one of the most exciting days in Tesla's history and we're just trying to figure out the right timing for that, Sentiment Score: 0.0
# Sentence  We think probably the right timing will be the -- probably the third week of May, Sentiment Score: 0.0
# Sentence  Not giving a firm date, but we think that probably that's the right timing, Sentiment Score: 0.0
# Sentence  And depending upon what we're allowed to do, it will either be in California or Texas, Sentiment Score: 0.0
# Sentence  Martin Viecha Okay, Sentiment Score: 0.0
# Sentence  And the last question from institutional investors, could you please update on progress stores development and commercialization of Full Self-Driving? How much revenue have you recognized so far? Zachary Kirkhorn So there is a couple of things on the financials for Full Self-Driving, Sentiment Score: 0.0
# Sentence  And so, currently, in North America, it's sold for $7,000 as an option, Sentiment Score: 0.0
# Sentence  We take roughly half of that as revenue, and the other half of it goes into deferred revenue, Sentiment Score: 1.0
# Sentence  That's associated with features that will be released with time, Sentiment Score: 0.0
# Sentence  Our deferred revenue balance is continuing to grow, Sentiment Score: 1.0
# Sentence  It's a little bit over $600 million, Sentiment Score: 0.0
# Sentence  And so as we release features with time, at the end of every quarter, we take a look at what features have been released associated value and then we can release that from the deferred revenue into our financials for that quarter, Sentiment Score: 0.0
# Sentence  And then cars going forward, once the feature is released, we can recognize that revenue, Sentiment Score: 0.0
# Sentence  So we reduce the amount of deferral, and we can recognize that revenue within period, Sentiment Score: 1.0
# Sentence  So, I mean, this is one of what we think will be one of the most powerful gross margin levers with time as the feature suite is rolled out, Sentiment Score: 1.0
# Sentence  Elon Musk Absolutely, Sentiment Score: 0.0
# Sentence  There's also a tremendous amount of untapped potential in the beat out there that could upgrade to turn on Autopilot -- basic Autopilot or Full Self-Driving, Sentiment Score: 0.0
# Sentence  And that's something we will enable just as simple in our purchase or as we talked about earlier, just towards the end of the year, as a subscription, Sentiment Score: 0.0
# Sentence  So that's just a lot of untapped potential there, Sentiment Score: 0.0
# Sentence  That's not in the deferred revenue line, obviously, but it's certainly a great deal deferred potential that we think is a large portion, which is likely to reach fruition, Sentiment Score: 0.0
# Sentence  Martin Viecha Thank you, Sentiment Score: 0.0
# Sentence  And now let's go through the questions from retail investors, Sentiment Score: 0.0
# Sentence  Question number one, Elon has mentioned a 50% compound annual growth target for Tesla in the past, Sentiment Score: 0.0
# Sentence  Is this still in line with Tesla's ambitions for the next five to 10 years? This would be 4 million vehicles in 2025 and more than 20 million vehicles in 2030, Sentiment Score: 0.0
# Sentence  Is 40% or more realistic target? Elon Musk Well, it's always difficult to predict what the macro situation is going to be, Sentiment Score: 0.0
# Sentence  I think people – actually people would have predicted the unexpected roundhouse that COVID came up with it sort of came out of nowhere, Sentiment Score: 0.0
# Sentence  So I think in the absence of something, some massive force majeure events, but quite massive, I think, 40% is the likely number, Sentiment Score: 1.0
# Sentence  It's possible that is 40%, Sentiment Score: 0.0
# Sentence  I would be very shocked, if it's less than 40%, even with force majeure Model 3, Sentiment Score: 2.0
# Sentence  Martin Viecha Okay, Sentiment Score: 0.0
# Sentence  The next question from retail investors, Sentiment Score: 0.0
# Sentence  When will you announce the next Giga? How many Gigas, do you have planned for the next five years? Elon Musk I think we will announce the next Giga possibly as soon as a month, Sentiment Score: 0.0
# Sentence  We may not – as soon as next month, Sentiment Score: -2.0
# Sentence  This is not a prediction, just saying, Sentiment Score: 0.0
# Sentence  That's – that could happen, Sentiment Score: 0.0
# Sentence  It will certainly be within three months and possibly one month, Sentiment Score: 0.0
# Sentence  And that would be in the U, Sentiment Score: 0.0
# Sentence S, Sentiment Score: 0.0
# Sentence  So as for how many will be in five years, I'm not – I don't know right now what that number would be, Sentiment Score: 0.0
# Sentence  I guess, several more than there are today, Sentiment Score: 0.0
# Sentence  But I'm not sure, what exactly it would be in five years, but some number more than today, Sentiment Score: 0.0
# Sentence  Zachary Kirkhorn I'll also add that our Gigas have gotten bigger, Sentiment Score: 0.0
# Sentence  And -- Elon Musk Yes, Sentiment Score: 0.0
# Sentence  Larger, they start being called Tera, Sentiment Score: 0.0
# Sentence  Zachary Kirkhorn Yes, with multiple products as well, Sentiment Score: 0.0
# Sentence  And so the absolute number of Giga factories, we may ultimately build might be less, but each one is larger, Sentiment Score: 0.0
# Sentence  And that's under our belief that just significant efficiencies by having as much as possible, and similar product lines under the same roof, and as much vertical integration as possible all in one facility, Sentiment Score: 0.0
# Sentence  Martin Viecha Thank you, Sentiment Score: 0.0
# Sentence  The next question is, can you give us an update on Solar Roof ramp? How many are you currently able to install per week? What is your installations per week target for the end of 2021? Elon Musk We were actually gaining interest momentum with the Solar Roof before COVID, but COVID essentially shut us down, both from the ability to install and the ability to get permits, Sentiment Score: 0.0
# Sentence  The permit offices were closed, Sentiment Score: 0.0
# Sentence  And we're sheltering places, 11 places, Sentiment Score: 0.0
# Sentence  So we obviously cannot install and the – if you can't get permits, then you can't physically do it, Sentiment Score: 0.0
# Sentence  It's basically impossible, Sentiment Score: -1.0
# Sentence  So – but I think the long-term trend for Solar Roof is extremely good, and I'm confident that, let's say, within the next, I don't know, year or—maybe even by end of year, we should be installing at a rate of 1,000 a week, Sentiment Score: 2.0
# Sentence  That's not in the middle of winter or something, like taking seasonality – allowing for seasonality, where it's hard to install on roofs that are covered in snow and ice, Sentiment Score: 0.0
# Sentence  But like, say spring, I think it's installing, which is the hard part, Sentiment Score: 0.0
# Sentence  We actually have demonstrated the ability to hit 1,000 a week plus build rate for the Solar Glass Roof already, Sentiment Score: 2.0
# Sentence  So that's not a problem, Sentiment Score: 0.0
# Sentence  It's building out the installed teams, building up the third-party channel installers, the roofing industry installers, Sentiment Score: 0.0
# Sentence  And internally, we want to have at least 1,000 Solar Roof install teams with – and taking a week or perhaps a little less than a week to do an install, which gets you 1,000 a week roof installations, Sentiment Score: 0.0
# Sentence  We see demand is good, Sentiment Score: 1.0
# Sentence  Production is good, Sentiment Score: 0.0
# Sentence  So it's really all about the install, and then like also build out the training, the very diverse group of companies in the roofing industry to also install Solar Roof that, I think will scale – allow us to scale far beyond 1,000 a week, Sentiment Score: 0.0
# Sentence  We're also seeing a lot of interest outside of North America, Sentiment Score: 0.0
# Sentence  So we expect this to be a product that is international and actually seeing a tremendous amount of interest from China on the Solar Roof, Sentiment Score: 1.0
# Sentence  So we're confident this will be a very significant product for the company over time, Sentiment Score: 1.0
# Sentence  Martin Viecha Thank you, Sentiment Score: 0.0
# Sentence  The next question is, can you elaborate on Tesla's plan to enter the residential and/or commercial HVAC market? Can you provide some basics of how your system will work? Will you consider the heat pump water heater market as well? Elon Musk Well, as I said on Twitter, I'm personally extremely excited to build HVAC – gas, HVAC system that also has sort of hospital-grade particle filtration, basically have a filtration that filters out viruses, bacteria, pollen, fungi and also neutralizes specific alkaline gases that is quiet and efficient, Sentiment Score: 0.0
# Sentence  And these are all things we've achieved in our cars, Sentiment Score: 0.0
# Sentence  In fact, I don't know if a lot of people realize, but the Model S are the only cars in the world that have a hospital operating room-grade heavy filters built-in, Sentiment Score: 0.0
# Sentence  They're very big, Sentiment Score: 0.0
# Sentence  So – but you can get to a particle count that is insanely low with our cars, Sentiment Score: 0.0
# Sentence  Zachary Kirkhorn And 3 and Y have like MERV 16 or 15 capable filter – Elon Musk Yeah, Sentiment Score: 0.0
# Sentence  It’s not like model 3 and Y – Model 3 and Y also – they're way better than any other cars to the best of my knowledge, Sentiment Score: 0.0
# Sentence  They're not quite as good as possible operating room, but they are extremely good, way better than any other normal car, Sentiment Score: 0.0
# Sentence  And we're continuing to improve the filters on 3 and Y, Sentiment Score: 0.0
# Sentence  These actually have a big effect on health even in normal just day-to-day living, Sentiment Score: 0.0
# Sentence  It's reducing particle count and it has vector on allergies and all sorts of things, Sentiment Score: 0.0
# Sentence  So it's really – air quality is incredibly important even in non-COVID situations going forward, Sentiment Score: 0.0
# Sentence  So taking all those things that we've replenished and applying to how HVAC would be and commercial HVAC would be is just very exciting, Sentiment Score: 0.0
# Sentence  And then you've got – if you're condensing water, like why not also have a few water source, if you have water, you possibly could then heat the water and have a water heater as well, Sentiment Score: 0.0
# Sentence  Zachary Kirkhorn Yeah, Sentiment Score: 0.0
# Sentence  And use it as a heat source, if you need it instead of the outdoors, when the outdoor is really cold or the other way around, Sentiment Score: 0.0
# Sentence  So lots of options, Sentiment Score: 0.0
# Sentence  Elon Musk It could be a hell of a product, Sentiment Score: 0.0
# Sentence  So we just have to – Tesla have potentially to whether we continue on the product front, Sentiment Score: 0.0
# Sentence  So we're going to make sure, we got a lot of ice in the fire here, for new products with the Cybertruck, Semi, new Roadster and the Gigafactories in various parts of the world and Model Y, Autopilot and the Solar Roof and… Zachary Kirkhorn New technologies, Sentiment Score: 0.0
# Sentence  Elon Musk Yeah, exactly, Sentiment Score: 0.0
# Sentence  Powerwall, Powerpack, Megapack, Sentiment Score: 0.0
# Sentence  We are seeing tremendous demand for stationary storage, more than we can supply, at least for 2020, Sentiment Score: 2.0
# Sentence  Martin Viecha Thank you, Sentiment Score: 0.0
# Sentence  And the last question from the retailers, when will Tesla start acquiring utilities like Hornsdale Power Reserve and most lending instead of selling them battery storage? Does it make sense for Tesla to buy bigger plants and convert them? Elon Musk Well, we haven't really thought about that yet, Sentiment Score: 0.0
# Sentence  It's not out of the question, but our brand is full, Sentiment Score: 0.0
# Sentence  Excuse me, sir, our brand is full, Sentiment Score: 0.0
# Sentence  That's not out of the question, Sentiment Score: 0.0
# Sentence  Our overarching goal is to help accelerate the advent of sustainable energy, Sentiment Score: 0.0
# Sentence  And the three elements of that are sustainable power generation, then you've got to store the power, stationary storage, Sentiment Score: 0.0
# Sentence  And then you've got to have electric transportation, Sentiment Score: 0.0
# Sentence  So -- and we don't have, like, say, specific market share goals or anything like that, Sentiment Score: 0.0
# Sentence  It's just to the degree that we can accelerate the advent of sustainable energy, we think that's a fundamental good for the world, and we want to do that as fast as possible, Sentiment Score: 0.0
# Sentence  But it's not, like you said, market share growth is a goal in and of itself, Sentiment Score: 0.0
# Sentence  It's just the faster this happens, the better the world will do, Sentiment Score: 0.0
# Sentence  Martin Viecha Thank you very much, Sentiment Score: 0.0
# Sentence  And I think now we can move to analyst questions, Sentiment Score: 0.0
# Sentence  Operator Thank you, Sentiment Score: 0.0
# Sentence  Our first question will come from Adam Jonas with Morgan Stanley, Sentiment Score: 0.0
# Sentence  Please go ahead, Sentiment Score: 0.0
# Sentence  Adam Jonas Thanks everybody, Sentiment Score: 0.0
# Sentence  I hope everyone's safe and healthy, Sentiment Score: 0.0
# Sentence  I got one question, one follow-up, Sentiment Score: 0.0
# Sentence  And I'd point out, I've had a root canal before, and I would agree, Elon, Sentiment Score: 0.0
# Sentence  It was less painful than buying a car, Sentiment Score: 0.0
# Sentence  Elon Musk I mean, really, it's -- yeah, exactly, Sentiment Score: 0.0
# Sentence  Adam Jonas It's a big problem, actually, Sentiment Score: 0.0
# Sentence  It's a big problem, Sentiment Score: 0.0
# Sentence  Different conversations, Sentiment Score: 0.0
# Sentence  Zach, first for you, any real-time update on company liquidity at the end of April? Some companies have given the circumstances, gone out of their way to give a little color on that, Sentiment Score: 0.0
# Sentence  I just want to give you a shot at that, and I got a follow-up, Sentiment Score: 0.0
# Sentence  Zachary Kirkhorn Yeah, Sentiment Score: 0.0
# Sentence  It's a fair question, Sentiment Score: 0.0
# Sentence  I don't have any additional color to provide, Sentiment Score: 0.0
# Sentence  So $8, Sentiment Score: 0.0
# Sentence 1 billion in cash and cash equivalents at the end of Q1, we're managing it very closely, Sentiment Score: 2.0
# Sentence  As I mentioned in my opening remarks, we do have an increase in inventory of vehicles that we were unable to deliver at the end of Q1, Sentiment Score: 0.0
# Sentence  So we're making progress delivering those through April, which is helpful for liquidity, Sentiment Score: 1.0
# Sentence  And as we've been looking at liquidity, we've been looking at this over the next 18 months, and there's ups and downs to the liquidity, Sentiment Score: 0.0
# Sentence  Currently now, as we're not producing, we still have payables from Q1 that we're paying off, Sentiment Score: 0.0
# Sentence  But then in a couple of months, we'll quickly be through that, and then we'll have a gap in payables since we don't have any parts coming in, Sentiment Score: 0.0
# Sentence  So it does go up and down a little bit, Sentiment Score: 0.0
# Sentence  But in looking at the long-term horizon, which is how we're managing it right now, we feel pretty comfortable with the liquidity position of the company, Sentiment Score: 1.0
# Sentence  Elon Musk Yeah, Sentiment Score: 0.0
# Sentence  I should say we are a bit worried about not being able to resume production in the Bay Area, and that should be identified as a serious risk, Sentiment Score: -2.0
# Sentence  We only have two car factories right now, one in Shanghai and one in the Bay Area, and the Bay Area produces the vast majority of our cars, all of S and X, and most of the 3 and all of the Y, Sentiment Score: 0.0
# Sentence  So the extension of the shelter in place or, frankly, I would call it, forcibly imprisoning people in their homes against all their constitutional rights, that in my opinion, and breaking people's freedoms in ways that are horrible and wrong is not why people came to America or built this country, what the fuck? Excuse me, Sentiment Score: 0.0
# Sentence  But outrage -- it’s an outrage, Sentiment Score: 0.0
# Sentence  So -- but it will cause great harm, not just to Tesla, but to many companies, Sentiment Score: -2.0
# Sentence  And while Tesla will weather the storm, there are many small companies that will not, Sentiment Score: -2.0
# Sentence  And all peoples -- everything people have worked for their whole life is going to get -- is being destroyed in real time, Sentiment Score: 0.0
# Sentence  And we're going to have many suppliers -- or have many suppliers that are having super hard times, especially the small ones, and it's causing a lot of strife to a lot of people, Sentiment Score: 0.0
# Sentence  Yes, Sentiment Score: 0.0
# Sentence  Adam Jonas Elon, on that point, you mentioned people that gave their lives to build the country, Sentiment Score: 0.0
# Sentence  My fault for you on this, Sentiment Score: 0.0
# Sentence  There have been a lot of comparisons drawn to the state of the U, Sentiment Score: 0.0
# Sentence S, Sentiment Score: 0.0
# Sentence  economy in the early 1930s when Roosevelt began a series of new deals and infrastructure projects or post-World War 2 when Eisenhower launched the U, Sentiment Score: 0.0
# Sentence S, Sentiment Score: 0.0
# Sentence  Highway Act and JFK launched the Apollo Program, which you could say was influenced by the Cold War, clearly, and you benefited from and our space program benefited from, Sentiment Score: 0.0
# Sentence  What would be your message to U, Sentiment Score: 0.0
# Sentence S, Sentiment Score: 0.0
# Sentence  lawmakers on this call as we – in addition to your opinion on shelter in place, but thinking the longer term, your message to U, Sentiment Score: 0.0
# Sentence S, Sentiment Score: 0.0
# Sentence  lawmakers coming out of the crisis, specifically around EV infrastructure and a chance to work with taxpayers to support sustainable transport and renewable energy? I'm wondering if you see this as a chance to make the crisis and all the loss and lives lost not be in vain, Sentiment Score: 0.0
# Sentence  Thanks, Sentiment Score: 0.0
# Sentence  Elon Musk I think, it's high time we invested in infrastructure in this country, Sentiment Score: 0.0
# Sentence  We have a lot of a crumbling highways and bridges, Sentiment Score: 0.0
# Sentence  And frankly, when I visit China, I see their infrastructure as being much better than ours, Sentiment Score: 0.0
# Sentence  It's great, Sentiment Score: 0.0
# Sentence  Europe has better infrastructure, Sentiment Score: 0.0
# Sentence  It's really quite sad that U, Sentiment Score: 0.0
# Sentence S, Sentiment Score: 0.0
# Sentence  infrastructure especially it’s roads and highways is where it is today, Sentiment Score: 0.0
# Sentence  And our airports, in a lot of cases, are an embarrassment, Sentiment Score: 0.0
# Sentence  So -- and it's not just a question of money, Sentiment Score: 0.0
# Sentence  It's a question of will, Sentiment Score: 0.0
# Sentence  Sometimes, we spend a lot of money on these things, but what are we gaining for it? So -- and yeah, we really need to be thinking about what is the transportation of the future, not the transportation of the past, Sentiment Score: 0.0
# Sentence  If this was 1920, do you want to be investing in steam engines or in commercial engines? Obviously that’s not steam engines, Sentiment Score: 0.0
# Sentence  So this is the time to think about the future and also to ask, is it right to infringe upon people's rights, as what is happening right now, Sentiment Score: 0.0
# Sentence  I think the people are going to be very angry about this and are very angry, because somebody should really -- if somebody wants to stay in their house, that's great, Sentiment Score: 0.0
# Sentence  They should be allowed to stay in the house, and they should not be compelled to leave, Sentiment Score: 0.0
# Sentence  But to say that they cannot leave their house, and they will be arrested if they do, this is fascist, Sentiment Score: 0.0
# Sentence  This is not democratic, Sentiment Score: 0.0
# Sentence  This is not freedom, Sentiment Score: 0.0
# Sentence  Give people back their goddamn freedom, Sentiment Score: 0.0
# Sentence  Martin Viecha Okay, Sentiment Score: 0.0
# Sentence  Let's go to the next question please, Sentiment Score: 0.0
# Sentence  Operator Thank you, Sentiment Score: 0.0
# Sentence  Our next question comes from Emmanuel Rosner with Deutsche Bank, Sentiment Score: 0.0
# Sentence  Please go ahead, Sentiment Score: 0.0
# Sentence  Emmanuel Rosner Hi, good evening, Sentiment Score: 0.0
# Sentence  Question on Model Y, Sentiment Score: 0.0
# Sentence  I was hoping you can elaborate a little bit more on the drivers of how the gross margin is already positive at such low volume, Sentiment Score: 0.0
# Sentence  How much of it is a function of the commonality with the Model 3, what other factors should we think about? And what does that mean for the app flow for the eventual gross margin on Model Y? Elon Musk Zach? Zachary Kirkhorn Sure, Sentiment Score: 0.0
# Sentence  A couple of thoughts there for Y, Sentiment Score: 0.0
# Sentence  The first is, it does carry a higher ASP, Sentiment Score: 0.0
# Sentence  So on the revenue side, it carries a higher ASP than Model 3, Sentiment Score: 0.0
# Sentence  And the deliveries that we started with were of the higher ASP versions of the cars, Sentiment Score: 0.0
# Sentence  So we started with deliveries of performance initially, Sentiment Score: 0.0
# Sentence  And so that helps create some of the margin, Sentiment Score: 0.0
# Sentence  And that will come down with time as more variants are released, and we have more of a steady-state mix, Sentiment Score: 0.0
# Sentence  But it's similar to the ASP trends that we had with Model 3 when we launched that product in Fremont two years ago, Sentiment Score: 0.0
# Sentence  On the cost side, I think you hit on a couple of the buckets, Sentiment Score: 0.0
# Sentence  The commonality is huge, Sentiment Score: 0.0
# Sentence  It's very important, Sentiment Score: 0.0
# Sentence  And in addition to that, manufacturing processes are very similar to Model 3 as well, and so we have experience with that both with Model 3 in Fremont and then as well in Shanghai, Sentiment Score: 0.0
# Sentence  And it helps to have an existing factory with existing workforce and knowledge here as well, Sentiment Score: 0.0
# Sentence  So the ecosystem to support and launch the product is there, Sentiment Score: 0.0
# Sentence  There remain a lot of opportunities to take -- continue to take costs out of the car, Sentiment Score: 1.0
# Sentence  And the number of vehicles that we built in the first quarter is quite limited relative to our goal, Sentiment Score: 0.0
# Sentence  Elon Musk It's good, Sentiment Score: 0.0
# Sentence  We take costs out of the car and to make the product better, Sentiment Score: 0.0
# Sentence  So it's tax, Sentiment Score: 0.0
# Sentence  It's not make the product worse, Sentiment Score: -1.0
# Sentence  It's -- and if we can take costs out of a car, make it worse, we want to take costs out of the car, figure out how we can make it lighter and simpler, Sentiment Score: 0.0
# Sentence  And so it's -- want the car to just incrementally improve as well as incrementally lowering costs, Sentiment Score: 0.0
# ...
# Sentence  Operator Ladies and gentlemen, please standby, your conference will resume momentarily, Sentiment Score: 0.0
# Sentence  Thank you, Sentiment Score: 0.0
# Sentence  Speakers, you're back online, Sentiment Score: 0.0
# Sentence  Martin Viecha All right, Sentiment Score: 0.0
# Sentence  Sorry, we got disconnected for some reason, Sentiment Score: 0.0
# Sentence  What was the question again? Okay, Sentiment Score: 0.0
# Sentence  Let's go to the next question, please, Sentiment Score: 0.0
# Sentence  Operator The next question comes from Ben Kallo with Baird, Sentiment Score: 0.0
# Sentence  Please go ahead, Sentiment Score: 0.0
# Sentence  Ben Kallo Hey, thank you very much, Sentiment Score: 0.0
# Sentence  Just wondering about the cell strategy, Sentiment Score: 0.0
# Sentence  In Reno, you have, obviously, integrated there, Sentiment Score: 0.0
# Sentence  But you're buying cells I think, in Shanghai and then what we think in Germany, Sentiment Score: 0.0
# Sentence  And so, how are you looking at that going forward? And then could you just talk about Mr, Sentiment Score: 0.0
# Sentence  Mizuho and that Board addition and kind of the process with adding him to the Board? Thank you, Sentiment Score: 0.0
# Sentence  Zachary Kirkhorn Sure, Sentiment Score: 0.0
# Sentence  From a sales perspective, with all the partners we've had historically in the future, we're just looking for competitive technology and competitive pricing, Sentiment Score: 0.0
# Sentence  I think we'll talk a little bit more about this on Battery Investor Day like how we're approaching all of it, Sentiment Score: 0.0
# Sentence  But yes, I mean, we don't have like one model we're restricting ourselves to pursue, Sentiment Score: 0.0
# Sentence  We're just trying to find what's best for the products and -- in the long run, Sentiment Score: 0.0
# Sentence  And then the other question about the Board? Martin Viecha Sorry, we couldn't hear the second part of the question, Sentiment Score: 0.0
# Sentence  Ben Kallo Yes, Sentiment Score: 0.0
# Sentence  I was asking about Mr, Sentiment Score: 0.0
# Sentence  Mizuho entering the Board and kind of the process behind that and what he brings to the Board? Elon Musk I think we all need to go, Sentiment Score: 0.0
# Sentence  And obviously, he brings tremendous amount of experience investing at the highest levels in the world and has done great work as -- at the Japan Pension Fund, which is the largest fund of any kind in the world, Sentiment Score: 0.0
# Sentence  And generally, the conversations over the years is just churning incredible insight into how the securities -- the global security markets work and what he thinks it is, whether are historical, Sentiment Score: 0.0
# Sentence  It just -- it seems like he has a strong philosophical understanding about how to make the future better, Sentiment Score: 0.0
# Sentence  And he shares our view regarding the environment and just a very sensible, smart person who brings a lot to the Board and I think is generally recognized as such by many people, Sentiment Score: 0.0
# Sentence  Ben Kallo I guess leaking into the Panasonic relationship, maybe just how is that relationship going? And is there any read-through on bringing him on to the Board? Thank you, Sentiment Score: 0.0
# Sentence  Elon Musk No, Sentiment Score: 0.0
# Sentence  I think this is set right through with the Panasonic relationship, Sentiment Score: 0.0
# Sentence  I mean, I have a great relationship with Panasonic's CEO, Sentiment Score: 0.0
# Sentence  We meet regularly one on one and talk at the time, Sentiment Score: 0.0
# Sentence  So, that relationship is strong, Sentiment Score: 0.0
# Sentence  Just that he'd bring more of a broader and a global, strategic view to the Board, Sentiment Score: 0.0
# Sentence  Martin Viecha Thank you, Sentiment Score: 0.0
# Sentence  Let's go to the next question, please, Sentiment Score: 0.0
# Sentence  Operator Our next question will come from Gene Munster with Loup Ventures, Sentiment Score: 0.0
# Sentence  Please go ahead, Sentiment Score: 0.0
# Sentence  Gene Munster Congratulations on the progress, Sentiment Score: 0.0
# Sentence  Elon, you talked about full autonomy by the end of the year, Sentiment Score: 0.0
# Sentence  I would love for you to walk through the rollout strategy of the Tesla Network app and how that's going to look prior to the robo taxi stage? Are you going to gradually take over human routes with autonomous capable routes over time? Or how do you see that playing out? Elon Musk Well, it's pretty much going to play out as it has played out, which is, we'll release more and more functionality, Sentiment Score: 0.0
# Sentence  Yes, before we release any functionality, it goes through extensive testing, Sentiment Score: 0.0
# Sentence  First, we run it -- we have a simulations team that has, I think, a very good simulation of the real world, Sentiment Score: 0.0
# Sentence  So we run any car changes through battery tests and simulation, Sentiment Score: 0.0
# Sentence  Then we have a global QA team, which I'm on, actually, Sentiment Score: 0.0
# Sentence  I'm one of -- on the global QA team, Sentiment Score: 0.0
# Sentence  And we test the releases in the real world, the essence of real-world in a simulation, which is -- which are very many, because the world is very complex and where -- and then we release it to a small group of private beta testers within the company; then to a larger audience, including people outside the company; then to Early Access Tesla owners; and then finally, a broad release, Sentiment Score: 0.0
# Sentence  And so there are many stages that these things go through, Sentiment Score: 0.0
# Sentence  So, by the time something is being -- going to wide release into the U, Sentiment Score: 0.0
# Sentence S, Sentiment Score: 0.0
# Sentence , it has gone through all of those stages, Sentiment Score: 0.0
# Sentence  And the software that's at the very early stage is much more advanced than what people are seeing, Sentiment Score: 0.0
# Sentence  So, just going to go through a very rigorous safety process, Sentiment Score: 0.0
# Sentence  So essentially, we need to figure out, get very good at complex intersections, get very good at complex turns in intersections and things like busy malls, in a parking lot or office park or special events and sporting events, that kind of thing, when those eventually come back, Sentiment Score: 0.0
# Sentence  Those are extra hard cases, Sentiment Score: 0.0
# Sentence  But it's all tracking very well, Sentiment Score: 1.0
# Sentence  If you like, the water pallets engineering team is -- we just have an extremely talented group, and I'm deeply involved with the team, Sentiment Score: 0.0
# Sentence  So we talk every week and meet every week when we can, as now physical meeting is difficult, Sentiment Score: 0.0
# Sentence  So I have quite a deep understanding where we are, where we're headed, Sentiment Score: 0.0
# Sentence  And I feel like we have a tremendous amount of momentum, and we'll have the functionality that’s really cool, also driving by the end of the year, Sentiment Score: 1.0
# Sentence  Now after that functionality is released, there's still another step, which is to improve the reliability of it, once it is released, to kind of core self-driving with the human -- supervised by the driver, Sentiment Score: 0.0
# Sentence  And then we keep improving the reliability to a point where it no longer needs to be supervised by the driver, Sentiment Score: 0.0
# Sentence  And we provide a vast body of data to regulators to show them that this is the case, Sentiment Score: 0.0
# Sentence  And then presumably, the regulators, depending on which jurisdiction it is, would give approval for the autonomous cars that can drive with no human onboard, Sentiment Score: 0.0
# Sentence  Obviously, the regulatory approval process that's difficult for us to predict with accuracy, because it's out of our hands, Sentiment Score: 0.0
# Sentence  But for the rest of it, I feel very good about where we are, Sentiment Score: 1.0
# Sentence  Gene Munster So, to summarize, we want -- we're going to give owners full autonomy, some level of that by the end of the year, Sentiment Score: 0.0
# Sentence  Then a human is in the loop, Tesla Network app sometime, is it first half of next year? Would that be the hope? Elon Musk Do you mean like, when can a car drive with no person? Gene Munster With a person -- initially a person who observes, would that be with the Tesla Network app, would that be really part of the year of 2021? Is that the hope? Elon Musk If described as a hope, I would say that, that's probably a fair description, Sentiment Score: 0.0
# Sentence  Gene Munster Okay, Sentiment Score: 0.0
# Sentence  And then kind of take it to its end stage, the robo taxi stage, Sentiment Score: 0.0
# Sentence  Any high-level thoughts to understand the regulatory is a massive unknown? But if you're going to put a guess on it, where would we -- when will we start seeing robo taxis? Elon Musk Well, I think it's quite likely, in my view, organic, Sentiment Score: 0.0
# Sentence  I could be wrong, Sentiment Score: 0.0
# Sentence  As you see, because we are ahead in some areas, and we're behind in others, because -- when I give a guess, I give the guess that I think is the likely midpoint, not the point with lots of margin, Sentiment Score: 0.0
# Sentence  If this is normal distribution, I'd give you the 50th percentile, not the three segment optimistic or pessimistic, Sentiment Score: 0.0
# Sentence  So then that necessarily means, at least, half of my predictions will be wrong and half will be right, Sentiment Score: 0.0
# Sentence  Yes, Sentiment Score: 0.0
# Sentence  I think -- or it might be right, but offset by a few weeks to a few months, in some cases a few years, Sentiment Score: 0.0
# Sentence  But I believe as everything I've ever said would come true – did come true, it may come through late, but it did come true, Sentiment Score: 0.0
# Sentence  So punctuality is not my strong suit, but I always come through in the end, Sentiment Score: 0.0
# Sentence  So – and I think we could see robo-taxi fleet in operation with the network fleet next year, Sentiment Score: 0.0
# Sentence  Not in all markets, but in some, Sentiment Score: 0.0
# Sentence  Martin Viecha Thank you, Sentiment Score: 0.0
# Sentence  And let’s go last question please, Sentiment Score: 0.0
# Sentence  Operator Our last question will come from Pierre Ferragu with New Street, Sentiment Score: 0.0
# Sentence  Please go ahead, Sentiment Score: 0.0
# Sentence  Pierre Ferragu Hey, thanks for taking my question, Sentiment Score: 0.0
# Sentence  One on gross margin, first, Sentiment Score: 0.0
# Sentence  I know your impressive performance in Q1, Sentiment Score: 0.0
# Sentence  So there are three moving parts, the tailwind from credits, of course; the Model Y is ramping, Sentiment Score: 0.0
# Sentence  Even if it broke even, it probably took average gross margin down, Sentiment Score: -1.0
# Sentence  And of course, you had like Fremont being closed, shut down the last week of the quarter, Sentiment Score: -2.0
# Sentence  It probably was the sort of an extra cost, Sentiment Score: 0.0
# Sentence  And so when I looked at how gross margin evolved sequentially, excluding these three moving parts, I felt like your auto gross margin could have been up like a couple of points sequentially, Sentiment Score: 0.0
# Sentence  So I wanted to check with you, if that estimate would make sense, Sentiment Score: 0.0
# Sentence  And then I will have a follow-up on energy storage, Sentiment Score: 0.0
# Sentence  Thank you, Sentiment Score: 0.0
# Sentence  Zachary Kirkhorn Sequential market improvement – margin improvement, Sentiment Score: 2.0
# Sentence  Elon Musk Yes, Sentiment Score: 0.0
# Sentence  Zachary Kirkhorn Yes, Sentiment Score: 0.0
# Sentence  So the three things that you mentioned, I had a little bit of a hard time hearing the full question here because we're having a bit of network difficulty in the room, Sentiment Score: 0.0
# Sentence  I'll do my best here, Sentiment Score: 0.0
# Sentence  So when we look at margin, we just look at credits as you have, so I agree with that, Sentiment Score: 0.0
# Sentence  Model Y ramping, bringing down overall gross margin, I agree with that as well, Sentiment Score: -1.0
# Sentence  So it was lower than the overall average, and that will increase with time, Sentiment Score: 0.0
# Sentence  And shutdown and efficiencies in both Shanghai and in Fremont also weighed on margin, Sentiment Score: -2.0
# Sentence  And the Shanghai margin was below the average as well, Sentiment Score: 0.0
# Sentence  Even though it's increasing quickly and approaching Model 3, it still is below the average, Sentiment Score: 0.0
# Sentence  And so I think the sentiment of your question was, if you were to remove those factors, was there a sequential increase in gross margin, Sentiment Score: 0.0
# Sentence  I haven't specifically calculated that, but I think your intuition is right, Sentiment Score: 0.0
# Sentence  We saw strength in gross margin across the board, as I mentioned, Sentiment Score: 1.0
# Sentence  And in particular, S and X gross margins continue to improve despite slightly lower volumes there and higher fixed cost amortization, Sentiment Score: 1.0
# Sentence  So there's good progress happening, both on the ASP side and the cost reduction side, for our products and production, Sentiment Score: 1.0
# Sentence  And I think this also lends itself to the power of the gross profit contribution to the company once we get through these inefficiencies, we get them on up and running again, we increase capacity so we can spread out fixed costs and continue to execute on cost reductions on our products, we feel very optimistic about that path going forward, Sentiment Score: 1.0
# Sentence  Pierre Ferragu Thanks, Sentiment Score: 0.0
# Sentence  And I had a quick follow-up on energy storage, if you can hear me well, Sentiment Score: 0.0
# Sentence  I think like – I can't remember – I think from the very first days I heard you on the call, you've always mentioned that demand for energy storage is always outstripping supply, and you have more orders than you can make, Sentiment Score: 0.0
# Sentence  And so I'm kind of thinking there will be – there should be an inflection point in that business at some point, and it's going to be driven by your ability to add much more manufacturing capacity like battery manufacturing capacity, Sentiment Score: 0.0
# Sentence  And at a high level, how are you thinking about that inflection point in terms of time line? Zachary Kirkhorn In terms of time line, I think what we've been doing with both our partners and internally is looking at how to reduce the – fundamentally the cost of investments in new sales capacity because when you look at a car – a vehicle product, there's a lot of things in the vehicle besides the cells, Sentiment Score: 0.0
# Sentence  When you look at an energy storage product, it's really just the cells, Sentiment Score: 0.0
# Sentence  And so to really grow the energy storage business, it's all about cell investments, Sentiment Score: 0.0
# Sentence  And so that's what we've been focused on, Sentiment Score: 0.0
# Sentence  And I think not to give too much away, but that will be one of the things we address in Battery Investor Day is how we're focused on that, Sentiment Score: 0.0
# Sentence  And when we have that in the place we want, it will be a lot easier to scale that business, Sentiment Score: 0.0
# Sentence  Martin Viecha Thank you very much for all your great questions, Sentiment Score: 0.0
# Sentence  Unfortunately, this is all the time we have today, and we'll speak to you again in three months' time, Sentiment Score: 0.0
# Sentence  Thank you very much, and have a good day, Sentiment Score: 0.0
# Sentence  Operator Ladies and gentlemen, this concludes today's conference call, Sentiment Score: 0.0
# Sentence  Thank you for your participation, Sentiment Score: 0.0
# Sentence  You may now disconnect, Sentiment Score: 0.0
# Sentence , Sentiment Score: 0.0
# 80.0

# %%
import pandas as pd

data = {
    "Q1_4_19_2023": 58.0,
    "Q4_1_25_2023": 76.0,
    "Q3_10_19_2022": 92.0,
    "Q2_7_20_2022": 58,
    "Q1_4_20_2022": 54.0,
    "Q4_1_26_2022": 60,
    "Q3_10_20_2021": 91.0,
    'Q2_7_26_2021':54,
    "Q1_4_26_2021": 57.0,
    "Q4_1_27_2021": 91.0,
    'Q3_10_21_2020': 90, 
    'Q2_7_22_2020': 63,
    'Q1_4_29_2020': 80.0,
    "Q4_1_29_2020": 60.0,
    "Q3_10_23_2019": 109.0,
    "Q2_7_24_2019": 99.0,
}

df = pd.DataFrame(data.items(), columns=['quarter_year', 'sentiment_value'])
df['quarter'] = df['quarter_year'].str.split('_', expand=True)[0]
df['year'] = df['quarter_year'].str.split('_', expand=True)[3]
df = df[['quarter_year', 'quarter', 'year', 'sentiment_value']]
df = df.drop(columns=['quarter_year'])
# Convert 'year' to integer for manipulation
df['year'] = df['year'].astype(int)

# Decrement 'year' by 1 where 'quarter' is 'Q4'
df.loc[df['quarter'] == 'Q4', 'year'] = df.loc[df['quarter'] == 'Q4', 'year'] - 1
# Convert sentiment data into a DataFrame
sentiment_df = pd.DataFrame(data.items(), columns=['quarter_year', 'sentiment_value'])

# Extract quarter and year from quarter_year
sentiment_df['quarter'] = sentiment_df['quarter_year'].str.split('_', expand=True)[0]
sentiment_df['year'] = sentiment_df['quarter_year'].str.split('_', expand=True)[3]

# Convert 'year' to integer for manipulation
sentiment_df['year'] = sentiment_df['year'].astype(int)

# Decrement 'year' by 1 where 'quarter' is 'Q4'
sentiment_df.loc[sentiment_df['quarter'] == 'Q4', 'year'] = sentiment_df.loc[sentiment_df['quarter'] == 'Q4', 'year'] - 1

sentiment_df['year'] = sentiment_df['year'].astype(str)

# %%
#!/usr/bin/env python
import pandas as pd
try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

import certifi
import json

def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

is_url = "https://financialmodelingprep.com/api/v3/income-statement/TSLA?period=quarter&limit=400&apikey=28d5e9c0188bdad19a8f0bded39a200a"
bs_url = "https://financialmodelingprep.com/api/v3/balance-sheet-statement/TSLA?period=quarter&limit=400&apikey=28d5e9c0188bdad19a8f0bded39a200a"
cfs_url = 'https://financialmodelingprep.com/api/v3/cash-flow-statement/TSLA?period=quarter&limit=400&apikey=28d5e9c0188bdad19a8f0bded39a200a'
fr_url = 'https://financialmodelingprep.com/api/v3/ratios/TSLA?period=quarter&limit=140&apikey=28d5e9c0188bdad19a8f0bded39a200a'
tsla_pricing_url = 'https://financialmodelingprep.com/api/v3/historical-price-full/TSLA?serietype=line&apikey=28d5e9c0188bdad19a8f0bded39a200a'
# Get the data as JSON
_is = get_jsonparsed_data(is_url)
bs = get_jsonparsed_data(bs_url)
cfs = get_jsonparsed_data(cfs_url)
fr = get_jsonparsed_data(fr_url)
tesla = get_jsonparsed_data(tsla_pricing_url)
# Convert the JSON to a DataFrame
income_statements = pd.json_normalize(_is)
income_statements = income_statements.drop(columns=['symbol', 'reportedCurrency', 'fillingDate', 'acceptedDate', 'cik', 'link', 'finalLink', 'generalAndAdministrativeExpenses', 'sellingAndMarketingExpenses', 'otherExpenses'])
income_statements = income_statements.drop(index=0)
income_statements = income_statements.iloc[:15]

# Convert the JSON to a DataFrame
balance_sheets = pd.json_normalize(bs)
balance_sheets = balance_sheets.drop(columns=['symbol', 'reportedCurrency', 'fillingDate', 'acceptedDate', 'cik', 'link', 'finalLink', 'minorityInterest'])
balance_sheets = balance_sheets.drop(index=0)
balance_sheets = balance_sheets.iloc[:15]

# Convert the JSON to a DataFrame
cash_flow_statement = pd.json_normalize(cfs)
cash_flow_statement = cash_flow_statement.drop(columns=['symbol', 'reportedCurrency', 'fillingDate', 'acceptedDate', 'cik', 'link', 'finalLink'])
cash_flow_statement = cash_flow_statement.drop(index=0)
cash_flow_statement = cash_flow_statement.iloc[:15]

# Convert the JSON to a DataFrame
financial_ratios = pd.json_normalize(fr)
financial_ratios = financial_ratios.drop(columns=['symbol'])
financial_ratios = financial_ratios.iloc[:16]
financial_ratios['calendarYear'] = financial_ratios['date'].apply(lambda x: x.split('-')[0])
# Merge the three dataframes on quarter and year
merged_df = pd.merge(income_statements, balance_sheets, on=['calendarYear', 'period'])
merged_df = pd.merge(merged_df, cash_flow_statement, on=['calendarYear', 'period'])
merged_df = pd.merge(merged_df, financial_ratios, on=['calendarYear', 'period'])
merged_df  = merged_df.rename(columns={'calendarYear':'year', 'period':'quarter'})
#_index('DATE', inplace=True)


tesla_df = pd.json_normalize(tesla['historical'])
from datetime import datetime, timedelta
from pandas.tseries.offsets import DateOffset
from pandas.tseries.offsets import BDay, DateOffset
from pandas.tseries.offsets import BDay, DateOffset

# Parse the date in tesla_df
tesla_df["date"] = pd.to_datetime(tesla_df["date"])

# Sort tesla_df by date
tesla_df = tesla_df.sort_values("date")

# Set 'date' as index and sort it
tesla_df.set_index('date', inplace=True)
tesla_df.sort_index(inplace=True)

# Initialize a new dictionary to store the results
new_data = {}

# For each date in data
for key in data.keys():
    # Parse the date from the key
    date_str = key.split("_")[1:]  # Split the key
    date_str = "-".join(date_str)  # Join the split parts with dashes
    date = pd.to_datetime(date_str)  # Convert to datetime using pandas

    # Get the initial stock price
    initial_price = tesla_df.loc[date, "close"]

    # Get the stock return for the dates that are 1 business day, 5 business days, 1 month, and 3 months after the date
    for i in range(4):
        if i == 0:
            next_date = date + BDay(1)  # Add 1 business day
        elif i == 1:
            next_date = date + BDay(5)  # Add 5 business days
        elif i == 2:
            next_date = date + DateOffset(months=1)  # Add 1 calendar month
        elif i == 3:
            next_date = date + DateOffset(months=3)  # Add 3 calendar months

        # Find the corresponding row in tesla_df
        row = tesla_df.asof(next_date)  # Use `asof` instead of directly matching date

        # If the row is not None
        if row is not None:
            # Get the stock price at the next date
            next_price = row["close"]

            # Calculate the return
            stock_return = (next_price - initial_price) / initial_price

            # Add the return to new_data
            new_data[key + "_" + str(i + 1)] = stock_return
import numpy as np
# Convert new_data to a DataFrame
df = pd.DataFrame.from_dict(new_data, orient='index', columns=['stock_return'])
df = df.reset_index()
df['quarter'] = df['index'].apply(lambda x: x.split('_')[0])
df['year'] = df['index'].apply(lambda x: x.split('_')[-2])
print(df.tail(30))
#1Day Difference
df['1DayDiff'] = df.apply(lambda x: x['stock_return'] if x['index'].split('_')[-1] == '1' else np.nan, axis=1)
# Grab the non-null 1DayDiff values and their corresponding index
one_day_diff_values = df.loc[df['1DayDiff'].notnull(), '1DayDiff']
one_day_diff_index = df.loc[df['1DayDiff'].notnull(), 'index']
# Create a new DataFrame from the non-null 1DayDiff values and their corresponding index
df_1daydiff = pd.DataFrame({'Index': one_day_diff_index, '1DayDiff': one_day_diff_values})
df_1daydiff['year'] = df_1daydiff['Index'].apply(lambda x: x.split('_')[-2])
df_1daydiff['quarter'] = df_1daydiff['Index'].apply(lambda x: x.split('_')[0])

#5Day Difference
df['5DayDiff'] = df.apply(lambda x: x['stock_return'] if x['index'].split('_')[-1] == '2' else np.nan, axis=1)
# Grab the non-null 1DayDiff values and their corresponding index
five_day_diff_values = df.loc[df['5DayDiff'].notnull(), '5DayDiff']
five_day_diff_index = df.loc[df['5DayDiff'].notnull(), 'index']
# Create a new DataFrame from the non-null 1DayDiff values and their corresponding index
df_5daydiff = pd.DataFrame({'Index': five_day_diff_index, '5DayDiff': five_day_diff_values})
df_5daydiff['year'] = df_5daydiff['Index'].apply(lambda x: x.split('_')[-2])
df_5daydiff['quarter'] = df_5daydiff['Index'].apply(lambda x: x.split('_')[0])

#1month difference
df['1MonthDiff'] = df.apply(lambda x: x['stock_return'] if x['index'].split('_')[-1] == '3' else np.nan, axis=1)
# Grab the non-null 1DayDiff values and their corresponding index
month_diff_values = df.loc[df['1MonthDiff'].notnull(), '1MonthDiff']
month_diff_index = df.loc[df['1MonthDiff'].notnull(), 'index']
# Create a new DataFrame from the non-null 1DayDiff values and their corresponding index
df_monthdiff = pd.DataFrame({'Index': month_diff_index, '1MonthDiff': month_diff_values})
df_monthdiff['year'] = df_monthdiff['Index'].apply(lambda x: x.split('_')[-2])
df_monthdiff['quarter'] = df_monthdiff['Index'].apply(lambda x: x.split('_')[0])

#3Month difference
df['3MonthDiff'] = df.apply(lambda x: x['stock_return'] if x['index'].split('_')[-1] == '4' else np.nan, axis=1)
# Grab the non-null 3MonthDiff values and their corresponding index
month3_diff_values = df.loc[df['3MonthDiff'].notnull(), '3MonthDiff']
month3_diff_index = df.loc[df['3MonthDiff'].notnull(), 'index']
# Create a new DataFrame from the non-null 3MonthDiff values and their corresponding index
df_month3diff = pd.DataFrame({'year': month3_diff_index.str.split('_').str[-2], 'quarter': month3_diff_index.str.split('_').str[0], '3MonthDiff': month3_diff_values})

# Merge the 1DayDiff, 5DayDiff, 1MonthDiff, and 3MonthDiff DataFrames on quarter and year
df_merged = pd.merge(df_1daydiff[['year', 'quarter', '1DayDiff']], df_5daydiff[['year', 'quarter', '5DayDiff']], on=['year', 'quarter'], how='inner')
df_merged1 = pd.merge(df_monthdiff[['year', 'quarter', '1MonthDiff']], df_month3diff[['year', 'quarter', '3MonthDiff']], on=['year', 'quarter'], how='inner')
df_merged = pd.merge(df_merged, df_merged1, on=['year', 'quarter'], how='outer')
# Inner join sentiment_df with df_merged on year and quarter
print(df_merged['year'].dtype)
print(df_merged['quarter'].dtype)
df_merged = pd.merge(df_merged, sentiment_df[['year', 'quarter', 'sentiment_value']], on=['year', 'quarter'], how='inner')
df_merged
# Out:
# <ipython-input-149-546772c5d5c5>:25: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
#               index  stock_return quarter  year
# 34   Q1_4_26_2021_3     -0.161298      Q1  2021
# 35   Q1_4_26_2021_4     -0.109157      Q1  2021
# 36   Q4_1_27_2021_1     -0.033246      Q4  2021
# 37   Q4_1_27_2021_2     -0.010958      Q4  2021
# 38   Q4_1_27_2021_3     -0.218316      Q4  2021
# 39   Q4_1_27_2021_4     -0.184480      Q4  2021
# 40  Q3_10_21_2020_1      0.007453      Q3  2020
# 41  Q3_10_21_2020_2     -0.039324      Q3  2020
# 42  Q3_10_21_2020_3      0.158456      Q3  2020
# 43  Q3_10_21_2020_4      0.999314      Q3  2020
# 44   Q2_7_22_2020_1     -0.049776      Q2  2020
# 45   Q2_7_22_2020_2     -0.058543      Q2  2020
# 46   Q2_7_22_2020_3      0.287409      Q2  2020
# 47   Q2_7_22_2020_4      0.337003      Q2  2020
# 48   Q1_4_29_2020_1     -0.023273      Q1  2020
# 49   Q1_4_29_2020_2     -0.022398      Q1  2020
# 50   Q1_4_29_2020_3      0.043086      Q1  2020
# 51   Q1_4_29_2020_4      0.872695      Q1  2020
# 52   Q4_1_29_2020_1      0.102962      Q4  2020
# 53   Q4_1_29_2020_2      0.264565      Q4  2020
# 54   Q4_1_29_2020_3      0.149744      Q4  2020
# 55   Q4_1_29_2020_4      0.377836      Q4  2020
# 56  Q3_10_23_2019_1      0.176692      Q3  2019
# 57  Q3_10_23_2019_2      0.236885      Q3  2019
# 58  Q3_10_23_2019_3      0.307680      Q3  2019
# 59  Q3_10_23_2019_4      1.246739      Q3  2019
# 60   Q2_7_24_2019_1     -0.136137      Q2  2019
# 61   Q2_7_24_2019_2     -0.087855      Q2  2019
# 62   Q2_7_24_2019_3     -0.201906      Q2  2019
# 63   Q2_7_24_2019_4      0.131380      Q2  2019
# object
# object
# <ipython-input-149-546772c5d5c5>:66: FutureWarning: Passing 'suffixes' which cause duplicate columns {'date_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = pd.merge(merged_df, financial_ratios, on=['calendarYear', 'period'])
#     year quarter  1DayDiff  5DayDiff  1MonthDiff  3MonthDiff  sentiment_value
# 0   2023      Q1 -0.097458 -0.148624   -0.066726   -0.066726             58.0
# 1   2022      Q3 -0.066475  0.011710   -0.188480   -0.427265             92.0
# 2   2022      Q2  0.097805  0.110384    0.198653   -0.162505             58.0
# 3   2022      Q1  0.032317 -0.097922   -0.320610   -0.240176             54.0
# 4   2022      Q4 -0.115542 -0.033870   -0.136056   -0.065062             76.0
# 5   2021      Q3  0.032571  0.198729    0.313306    0.150693             91.0
# 6   2021      Q2 -0.019525  0.079149    0.066208    0.548660             54.0
# 7   2021      Q1 -0.045327 -0.072203   -0.161298   -0.109157             57.0
# 8   2021      Q4 -0.033246 -0.010958   -0.218316   -0.184480             60.0
# 9   2020      Q3  0.007453 -0.039324    0.158456    0.999314             90.0
# 10  2020      Q2 -0.049776 -0.058543    0.287409    0.337003             63.0
# 11  2020      Q1 -0.023273 -0.022398    0.043086    0.872695             80.0
# 12  2020      Q4  0.102962  0.264565    0.149744    0.377836             91.0
# 13  2019      Q3  0.176692  0.236885    0.307680    1.246739            109.0
# 14  2019      Q2 -0.136137 -0.087855   -0.201906    0.131380             99.0

# %%
correlation_df = df_merged.corrwith(df_merged['sentiment_value'])
print(correlation_df)
# Out:
# 1DayDiff           0.235874
# 5DayDiff           0.473128
# 1MonthDiff         0.320071
# 3MonthDiff         0.478766
# sentiment_value    1.000000
# dtype: float64
# <ipython-input-147-29c73f8d46d0>:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_df = df_merged.corrwith(df_merged['sentiment_value'])

# %%
# Reset the index of return_df to make 'date_offset' a column
df = df.reset_index()

# Create 'quarter_year' column by removing the suffixes
df['quarter_year'] = df['date_offset'].apply(lambda x: '_'.join(x.split('_')[:4]))

# Now you can merge them on 'quarter_year'
merged_df = pd.merge(sentiment_df, df, on='quarter_year')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date_offset'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-b13eba45e89f> in <cell line: 5>()
#       3
#       4 # Create 'quarter_year' column by removing the suffixes
# ----> 5 df['quarter_year'] = df['date_offset'].apply(lambda x: '_'.join(x.split('_')[:4]))
#       6
#       7 # Now you can merge them on 'quarter_year'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'date_offset'
